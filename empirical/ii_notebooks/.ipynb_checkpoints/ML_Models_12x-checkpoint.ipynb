# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import os 
import sys

import warnings
warnings.filterwarnings('ignore')

# %%
append_path= os.path.dirname(os.getcwd())
sys.path.append(append_path)

# %%
data_path = os.path.join(append_path,"data/train_test")

# %%
X_train = os.path.join(data_path,"X_train.csv")
X_test = os.path.join(data_path,"X_test.csv")
y_train = os.path.join(data_path,"y_train.csv")
y_test = os.path.join(data_path,"y_test.csv")

# %%
X_train = pd.read_csv(X_train)
X_test = pd.read_csv(X_test)
y_train = pd.read_csv(y_train)
y_test = pd.read_csv(y_test)

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train, y_train)

y_pred = svc.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

svc_train_acc = accuracy_score(y_train, svc.predict(X_train))
svc_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Support Vector Classifier is : {svc_train_acc}")
print(f"Test accuracy of Support Vector Classifier is : {svc_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Support Vector Classifier is : 0.8546666666666667
# Test accuracy of Support Vector Classifier is : 0.78
# [[195   0]
#  [ 55   0]]
#               precision    recall  f1-score   support
#
#            N       0.78      1.00      0.88       195
#            Y       0.00      0.00      0.00        55
#
#     accuracy                           0.78       250
#    macro avg       0.39      0.50      0.44       250
# weighted avg       0.61      0.78      0.68       250

# %%
#Quick check for overfitting due to Greater Than > 5-10% difference in Training & Test  accuracy score:

from sklearn.model_selection import cross_val_score

# Compute cross-validation scores (on training data)
cv_scores = cross_val_score(svc, X_train, y_train, cv=5, scoring='accuracy')

# Print results
print(f"Cross-Validation Scores: {cv_scores}")
print(f"CV Mean Accuracy: {cv_scores.mean():.2f}")
print(f"CV Standard Deviation: {cv_scores.std():.2f}")

# Now train on the full training set and evaluate on test data
svc.fit(X_train, y_train)
test_accuracy = svc.score(X_test, y_test)
print(f"Test Set Accuracy: {test_accuracy:.2f}")
# Out:
# Cross-Validation Scores: [0.75333333 0.76       0.74       0.72       0.73333333]
# CV Mean Accuracy: 0.74
# CV Standard Deviation: 0.01
# Test Set Accuracy: 0.78

# %%
cv_scores
#how do you tell these 5x scores are for training set vs validation set
#comparing it to the learning curve you can tell its for the validation set, the hold-out fold.
# Out:
# array([0.75333333, 0.76      , 0.74      , 0.72      , 0.73333333])

# %% [markdown]
# * Model trained and evaluated on 5x different folds of the training data
#     * The models accuracy varies slightly across folds 72% to 76%
#     * This suggests consistent performance across different folds of the data (No Major Instability)
# * CV Mean Accuracy score 74%. This is now the baseline expectation for how this model will perform on new, similar data.
# * The small standard deviation (±1%) and test performance suggest the model is stable and generalizes well.
#     * Low Variability: The model is stable and not highly sensitive to how the data is split.
#     * High Variability: ex: +/- 10%, this would indicate instability or dependence on specific data subsets (folds)
# * Conclusion: No Overfitting. Overfitting would show high training accuracy & low test accuracy, indicating model overfits the training data.

# %%
from sklearn.model_selection import learning_curve  
train_sizes, train_scores, val_scores = learning_curve(svc, X_train, y_train, cv=5)  
plt.plot(train_sizes, train_scores.mean(axis=1), label='Train')  
plt.plot(train_sizes, val_scores.mean(axis=1), label='Validation')  
plt.show()

# %%
# Generate learning curve data
#Learning Curve: Plot shows how a models performance score as the training set sample size increases.
#This shows us the evolution of the 2x scores as the sample size of training observations increases.
#Note, the error is less with smaller training size because EX: We take one single instance from the 
    #training set and use it to estimate a model. The error on the training instance will be 0/Very Low,
    #since it's quite easy to perfectly fit a single data point. The Validation Set sapmle size remains the
    #same through out all iteartions of training, thus error on validation set will be very large compared to
    #one instance example.
#A learning curve shows how error changes as the training set size increases.
#Training set n=60, 195, 330, 465, 600.
    #As we increase the training set size, the model cannot fit perfectly anymore the training set.
    #So the training error becomes larger. However, the model is trained on more data, 
    #so it manages to fit better the validation set. Thus, the validation error decreases.
#Learning curves give us an opportunity to diagnose bias and variance in supervised learning models. 
train_sizes, train_scores, val_scores = learning_curve(
    svc, X_train, y_train, cv=5, scoring='accuracy'
)
#cv=5: Data is split into 5 folds (5x groups within), 1x fold is the hold-out fold & used for validation,
    #5x folds within thus 5x training splits/rounds across

#train_scores: This is the subset used for training & models predictions compared to true labels
#val_score: This is the score on the subset not used in training set, isolated for "grading" (held out fold)

# Calculate means and standard deviations
train_mean = train_scores.mean(axis=1)
train_std = train_scores.std(axis=1)
val_mean = val_scores.mean(axis=1)
val_std = val_scores.std(axis=1)

# Plot learning curve
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, label='Training Score', color='blue')
plt.plot(train_sizes, val_mean, label='Validation Score', color='orange')

# Add shaded areas for standard deviation
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.1, color='blue')
plt.fill_between(train_sizes, val_mean - val_std, val_mean + val_std, alpha=0.1, color='orange')

# Find the index of the minimum validation score (the "turning point")
min_val_idx = np.argmin(train_mean)
training_size_at_min = train_sizes[min_val_idx]

#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# Add vertical line at the turning point
plt.axvline(
    x=training_size_at_min, 
    color='red', 
    linestyle='--', 
    label=f'{training_size_at_min}: Point of\nIntersection'
)

#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# Add labels and legend
plt.xlabel('Training Samples', fontsize=12)
plt.ylabel('Percent Correct (Accuracy)', fontsize=12)
plt.title('Learning Curve (SVC)',loc = "left", fontsize=18)
plt.legend(loc='upper right')
plt.grid(False)
plt.show()

#NOTE: The x-axis does NOT represent the validation set size—it shows how much data the model was trained on
#The validation set size perfold is always, For cv=5, the validation set size per fold is always len(X_train) // 5.
    #Thus 750 // 5 = 150 in this case.

# %% [markdown]
# * Big Gap between the scores indicates Overfitting.

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 30)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

knn_train_acc = accuracy_score(y_train, knn.predict(X_train))
knn_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of KNN is : {knn_train_acc}")
print(f"Test accuracy of KNN is : {knn_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of KNN is : 0.744
# Test accuracy of KNN is : 0.78
# [[195   0]
#  [ 55   0]]
#               precision    recall  f1-score   support
#
#            N       0.78      1.00      0.88       195
#            Y       0.00      0.00      0.00        55
#
#     accuracy                           0.78       250
#    macro avg       0.39      0.50      0.44       250
# weighted avg       0.61      0.78      0.68       250

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)

y_pred = dtc.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

dtc_train_acc = accuracy_score(y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Decision Tree is : {dtc_train_acc}")
print(f"Test accuracy of Decision Tree is : {dtc_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Decision Tree is : 1.0
# Test accuracy of Decision Tree is : 0.696
# [[144  51]
#  [ 25  30]]
#               precision    recall  f1-score   support
#
#            N       0.85      0.74      0.79       195
#            Y       0.37      0.55      0.44        55
#
#     accuracy                           0.70       250
#    macro avg       0.61      0.64      0.62       250
# weighted avg       0.75      0.70      0.71       250

# %%
#HYPERPARAMETER Tuning

from sklearn.model_selection import GridSearchCV

grid_params = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [3, 5, 7, 10],
    'min_samples_split' : range(2, 10, 1),
    'min_samples_leaf' : range(2, 10, 1)
}

grid_search = GridSearchCV(dtc, grid_params, cv = 5, n_jobs = -1, verbose = 1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %%
# best parameters and best score

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 8, 'min_samples_split': 2}
# 0.8066666666666666

# %%
# best estimator 

dtc = grid_search.best_estimator_

y_pred = dtc.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

dtc_train_acc = accuracy_score(y_train, dtc.predict(X_train))
dtc_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Decision Tree is : {dtc_train_acc}")
print(f"Test accuracy of Decision Tree is : {dtc_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Decision Tree is : 0.8066666666666666
# Test accuracy of Decision Tree is : 0.74
# [[143  52]
#  [ 13  42]]
#               precision    recall  f1-score   support
#
#            N       0.92      0.73      0.81       195
#            Y       0.45      0.76      0.56        55
#
#     accuracy                           0.74       250
#    macro avg       0.68      0.75      0.69       250
# weighted avg       0.81      0.74      0.76       250

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rand_clf = RandomForestClassifier(criterion= 'entropy', max_depth= 10, max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 3, n_estimators= 140)
rand_clf.fit(X_train, y_train)

y_pred = rand_clf.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

rand_clf_train_acc = accuracy_score(y_train, rand_clf.predict(X_train))
rand_clf_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Random Forest is : {rand_clf_train_acc}")
print(f"Test accuracy of Random Forest is : {rand_clf_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Random Forest is : 0.9653333333333334
# Test accuracy of Random Forest is : 0.772
# [[159  36]
#  [ 21  34]]
#               precision    recall  f1-score   support
#
#            N       0.88      0.82      0.85       195
#            Y       0.49      0.62      0.54        55
#
#     accuracy                           0.77       250
#    macro avg       0.68      0.72      0.70       250
# weighted avg       0.80      0.77      0.78       250

# %% [markdown]
# # Ada Boost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# Suppress warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings("ignore", category=DataConversionWarning)
warnings.filterwarnings("ignore", category=FutureWarning)


ada = AdaBoostClassifier(estimator = dtc)

parameters = {
    'n_estimators' : [50, 70, 90, 120, 180, 200],
    'learning_rate' : [0.001, 0.01, 0.1, 1, 10],
    'algorithm' : ['SAMME', 'SAMME.R']
}

grid_search = GridSearchCV(ada, parameters, n_jobs = -1, cv = 5, verbose = 1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# /Users/ericklopez/Desktop/Insurance_Fraud_Detection/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/ericklopez/Desktop/Insurance_Fraud_Detection/venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/ericklopez/Desktop/Insurance_Fraud_Detection/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# best parameter and best score

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.001, 'n_estimators': 90}
# 0.8066666666666666

# %%
# best estimator 

ada = grid_search.best_estimator_

y_pred = ada.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

ada_train_acc = accuracy_score(y_train, ada.predict(X_train))
ada_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Ada Boost is : {ada_train_acc}")
print(f"Test accuracy of Ada Boost is : {ada_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Ada Boost is : 0.8066666666666666
# Test accuracy of Ada Boost is : 0.74
# [[143  52]
#  [ 13  42]]
#               precision    recall  f1-score   support
#
#            N       0.92      0.73      0.81       195
#            Y       0.45      0.76      0.56        55
#
#     accuracy                           0.74       250
#    macro avg       0.68      0.75      0.69       250
# weighted avg       0.81      0.74      0.76       250

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)

# accuracy score, confusion matrix and classification report of gradient boosting classifier

gb_acc = accuracy_score(y_test, gb.predict(X_test))

print(f"Training Accuracy of Gradient Boosting Classifier is {accuracy_score(y_train, gb.predict(X_train))}")
print(f"Test Accuracy of Gradient Boosting Classifier is {gb_acc} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, gb.predict(X_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, gb.predict(X_test))}")
# Out:
# Training Accuracy of Gradient Boosting Classifier is 0.9373333333333334
# Test Accuracy of Gradient Boosting Classifier is 0.36
#
# Confusion Matrix :-
# [[ 43 152]
#  [  8  47]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            N       0.84      0.22      0.35       195
#            Y       0.24      0.85      0.37        55
#
#     accuracy                           0.36       250
#    macro avg       0.54      0.54      0.36       250
# weighted avg       0.71      0.36      0.35       250

# %% [markdown]
# # Stochastic Gradient Boosting (SGB)

# %%
sgb = GradientBoostingClassifier(subsample = 0.90, max_features = 0.70)
sgb.fit(X_train, y_train)

# accuracy score, confusion matrix and classification report of stochastic gradient boosting classifier

sgb_acc = accuracy_score(y_test, sgb.predict(X_test))

print(f"Training Accuracy of Stochastic Gradient Boosting: {accuracy_score(y_train, sgb.predict(X_train))}")
print(f"Test Accuracy of Stochastic Gradient Boosting: {sgb_acc} \n")

print(f"Confusion Matrix: \n{confusion_matrix(y_test, sgb.predict(X_test))}\n")
print(f"Classification Report: \n {classification_report(y_test, sgb.predict(X_test))}")
# Out:
# Training Accuracy of Stochastic Gradient Boosting: 0.936
# Test Accuracy of Stochastic Gradient Boosting: 0.388
#
# Confusion Matrix:
# [[ 48 147]
#  [  6  49]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            N       0.89      0.25      0.39       195
#            Y       0.25      0.89      0.39        55
#
#     accuracy                           0.39       250
#    macro avg       0.57      0.57      0.39       250
# weighted avg       0.75      0.39      0.39       250

# %%
#print(sys.executable)

# %% [markdown]
# # CatBoost

# %%
from catboost import CatBoostClassifier

cat = CatBoostClassifier(iterations=10)
cat.fit(X_train, y_train)
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.5723384	total: 60.4ms	remaining: 543ms
# 1:	learn: 0.4641248	total: 62.2ms	remaining: 249ms
# 2:	learn: 0.4294852	total: 64.1ms	remaining: 150ms
# 3:	learn: 0.4001329	total: 66ms	remaining: 99ms
# 4:	learn: 0.3757814	total: 67.7ms	remaining: 67.7ms
# 5:	learn: 0.3576658	total: 69.5ms	remaining: 46.4ms
# 6:	learn: 0.3327852	total: 71.4ms	remaining: 30.6ms
# 7:	learn: 0.3114915	total: 73.9ms	remaining: 18.5ms
# 8:	learn: 0.2933474	total: 76.8ms	remaining: 8.54ms
# 9:	learn: 0.2715013	total: 78.6ms	remaining: 0us

# %%
# accuracy score, confusion matrix and classification report of cat boost

cat_acc = accuracy_score(y_test, cat.predict(X_test))

print(f"Training Accuracy of Cat Boost Classifier is {accuracy_score(y_train, cat.predict(X_train))}")
print(f"Test Accuracy of Cat Boost Classifier is {cat_acc} \n")

print(f"Confusion Matrix : \n{confusion_matrix(y_test, cat.predict(X_test))}\n")
print(f"Classification Report : \n {classification_report(y_test, cat.predict(X_test))}")
# Out:
# Training Accuracy of Cat Boost Classifier is 0.9066666666666666
# Test Accuracy of Cat Boost Classifier is 0.692
#
# Confusion Matrix :
# [[135  60]
#  [ 17  38]]
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            N       0.89      0.69      0.78       195
#            Y       0.39      0.69      0.50        55
#
#     accuracy                           0.69       250
#    macro avg       0.64      0.69      0.64       250
# weighted avg       0.78      0.69      0.72       250

# %% [markdown]
# # ExtaTrees Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

etc = ExtraTreesClassifier()
etc.fit(X_train, y_train)

# accuracy score, confusion matrix and classification report of extra trees classifier

etc_acc = accuracy_score(y_test, etc.predict(X_test))

print(f"Training Accuracy of Extra Trees Classifier is {accuracy_score(y_train, etc.predict(X_train))}")
print(f"Test Accuracy of Extra Trees Classifier is {etc_acc} \n")

print(f"Confusion Matrix :- \n{confusion_matrix(y_test, etc.predict(X_test))}\n")
print(f"Classification Report :- \n {classification_report(y_test, etc.predict(X_test))}")
# Out:
# Training Accuracy of Extra Trees Classifier is 1.0
# Test Accuracy of Extra Trees Classifier is 0.776
#
# Confusion Matrix :-
# [[162  33]
#  [ 23  32]]
#
# Classification Report :-
#                precision    recall  f1-score   support
#
#            N       0.88      0.83      0.85       195
#            Y       0.49      0.58      0.53        55
#
#     accuracy                           0.78       250
#    macro avg       0.68      0.71      0.69       250
# weighted avg       0.79      0.78      0.78       250

# %% [markdown]
# # Light Gradient Boost Machine (LGBM)

# %%
from lightgbm import LGBMClassifier

lgbm = LGBMClassifier(learning_rate = 1)
lgbm.fit(X_train, y_train)

# accuracy score, confusion matrix and classification report of lgbm classifier

lgbm_acc = accuracy_score(y_test, lgbm.predict(X_test))

print(f"Training Accuracy of LGBM Classifier is {accuracy_score(y_train, lgbm.predict(X_train))}")
print(f"Test Accuracy of LGBM Classifier is {lgbm_acc} \n")

print(f"{confusion_matrix(y_test, lgbm.predict(X_test))}\n")
print(classification_report(y_test, lgbm.predict(X_test)))
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 192, number of negative: 558
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000144 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1385
# [LightGBM] [Info] Number of data points in the train set: 750, number of used features: 53
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.256000 -> initscore=-1.066864
# [LightGBM] [Info] Start training from score -1.066864
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# # Voting Classifier

# %%
from sklearn.ensemble import VotingClassifier

classifiers = [('Support Vector Classifier', svc), ('KNN', knn),  ('Decision Tree', dtc), ('Random Forest', rand_clf),
               ('Ada Boost', ada), ('XGboost', xgb), ('Gradient Boosting Classifier', gb), ('SGB', sgb),
               ('Cat Boost', cat), ('Extra Trees Classifier', etc), ('LGBM', lgbm)]

vc = VotingClassifier(estimators = classifiers)
vc.fit(X_train, y_train)

y_pred = vc.predict(X_test)
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.5723384	total: 2.41ms	remaining: 21.7ms
# 1:	learn: 0.4641248	total: 4.16ms	remaining: 16.6ms
# 2:	learn: 0.4294852	total: 6.04ms	remaining: 14.1ms
# 3:	learn: 0.4001329	total: 7.8ms	remaining: 11.7ms
# 4:	learn: 0.3757814	total: 9.66ms	remaining: 9.66ms
# 5:	learn: 0.3576658	total: 11.5ms	remaining: 7.65ms
# 6:	learn: 0.3327852	total: 13.3ms	remaining: 5.7ms
# 7:	learn: 0.3114915	total: 15ms	remaining: 3.75ms
# 8:	learn: 0.2933474	total: 16.7ms	remaining: 1.86ms
# 9:	learn: 0.2715013	total: 18.5ms	remaining: 0us
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 192, number of negative: 558
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000111 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1385
# ...

# %%
# accuracy_score, confusion_matrix and classification_report

vc_train_acc = accuracy_score(y_train, vc.predict(X_train))
vc_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Voting Classifier is : {vc_train_acc}")
print(f"Test accuracy of Voting Classifier is : {vc_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Voting Classifier is : 0.9466666666666667
# Test accuracy of Voting Classifier is : 0.736
# [[142  53]
#  [ 13  42]]
#               precision    recall  f1-score   support
#
#            N       0.92      0.73      0.81       195
#            Y       0.44      0.76      0.56        55
#
#     accuracy                           0.74       250
#    macro avg       0.68      0.75      0.69       250
# weighted avg       0.81      0.74      0.76       250

# %% [markdown]
# # XGBoost

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the encoder
le = LabelEncoder()

# Encode y_train and y_test (if needed)
y_train_encoded = le.fit_transform(y_train)  # Converts 'N' → 0, 'Y' → 1
y_test_encoded = le.transform(y_test)

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train, y_train_encoded)

y_pred = xgb.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

xgb_train_acc = accuracy_score(y_train_encoded, xgb.predict(X_train))
xgb_test_acc = accuracy_score(y_test_encoded, y_pred)

print(f"Training accuracy of XgBoost is : {xgb_train_acc}")
print(f"Test accuracy of XgBoost is : {xgb_test_acc}")

print(confusion_matrix(y_test_encoded, y_pred))
print(classification_report(y_test_encoded, y_pred))
# Out:
# Training accuracy of XgBoost is : 1.0
# Test accuracy of XgBoost is : 0.704
# [[146  49]
#  [ 25  30]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.75      0.80       195
#            1       0.38      0.55      0.45        55
#
#     accuracy                           0.70       250
#    macro avg       0.62      0.65      0.62       250
# weighted avg       0.75      0.70      0.72       250

# %%
param_grid = {"n_estimators": [10, 50, 100, 130], "criterion": ['gini', 'entropy'],
                               "max_depth": range(2, 10, 1)}

grid = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=5,  verbose=3,n_jobs=-1)
grid_search.fit(X_train, y_train_encoded)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# /Users/ericklopez/Desktop/Insurance_Fraud_Detection/venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/ericklopez/Desktop/Insurance_Fraud_Detection/venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# /Users/ericklopez/Desktop/Insurance_Fraud_Detection/venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# ...

# %%
# best estimator 

xgb = grid_search.best_estimator_

y_pred = xgb.predict(X_test)

# %%
# accuracy_score, confusion_matrix and classification_report

xgb_train_acc = accuracy_score(y_train_encoded, xgb.predict(X_train))
xgb_test_acc = accuracy_score(y_test_encoded, y_pred)

print(f"Training accuracy of XgBoost is : {xgb_train_acc}")
print(f"Test accuracy of XgBoost is : {xgb_test_acc}")

print(confusion_matrix(y_test_encoded, y_pred))
print(classification_report(y_test_encoded, y_pred))
# Out:
# Training accuracy of XgBoost is : 0.8066666666666666
# Test accuracy of XgBoost is : 0.74
# [[143  52]
#  [ 13  42]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.81       195
#            1       0.45      0.76      0.56        55
#
#     accuracy                           0.74       250
#    macro avg       0.68      0.75      0.69       250
# weighted avg       0.81      0.74      0.76       250

# %% [markdown]
# # Comparing Model Scores

# %%
models = pd.DataFrame({
    'Model' : ['SVM', 'KNN', 'Decision Tree', 'Random Forest','Ada Boost', 'Gradient Boost', 'Stochastic Gradient Boost', 'Cat Boost', 'Extra Trees', 'LGBM', 'XgBoost', 'Voting Classifier'],
    'Score' : [svc_test_acc, knn_test_acc, dtc_test_acc, rand_clf_test_acc, ada_test_acc, gb_acc, sgb_acc, cat_acc, etc_acc, lgbm_acc, xgb_test_acc, vc_test_acc]
})


models.sort_values(by = 'Score', ascending = False)
# Out:
#                         Model  Score
# 0                         SVM  0.780
# 1                         KNN  0.780
# 8                 Extra Trees  0.776
# 3               Random Forest  0.772
# 2               Decision Tree  0.740
# 4                   Ada Boost  0.740
# 10                    XgBoost  0.740
# 11          Voting Classifier  0.736
# 7                   Cat Boost  0.692
# 9                        LGBM  0.612
# 6   Stochastic Gradient Boost  0.388
# 5              Gradient Boost  0.360

# %%
# Create sorted dataframe
sorted_models = models.sort_values(by='Score', ascending=False)

# Create horizontal bar plot
plt.figure(figsize=(12, 8))
sns.set_style("whitegrid")

# Create barplot
ax = sns.barplot(x='Score', y='Model', data=sorted_models, palette="Blues_d")

# Add value labels
for i, v in enumerate(sorted_models['Score']):
    ax.text(v + 0.01, i, f"{v:.2%}", color='black', ha='left', va='center')

# Formatting
plt.title('Model Accuracy Comparison', loc="left", fontsize=18, pad=20)
plt.xlabel('Accuracy Score', fontsize=16)
plt.ylabel('Model', fontsize=16)
plt.xlim(0, 1)  # Assuming scores are between 0-1 (if percentages, use 0-100)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine(left=True)

plt.tight_layout()
plt.show()
